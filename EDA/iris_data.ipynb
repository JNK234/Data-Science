# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import os

# %%
data=pd.read_csv('iris.data')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.shape
# Out:
# (150, 5)

# %%
print(data.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data["species"].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
#It is a balanced dataset
#No of data points in every class is equal Therefore it is balanced dataset

# %%
#scatter plot using matplot lib
data.plot(kind="scatter",x="sepal_length",y="sepal_width").grid()
plt.show()
#The following graph is not clear as we connot distuinguish between the 3 classes
######NOT RECCOMENED###

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data,hue="species",size=4).map(plt.scatter,'petal_length','petal_width').add_legend();
plt.show();
#2D PLOT ####

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data,hue="species",size=4).map(plt.scatter,'sepal_length','sepal_width').add_legend();
plt.show();

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(data,hue='species',height=4);
plt.show();

# %%
#Pair plots are used to visualise all possible combination of features in pairs graphically

# %%
#Limitation of Pair-Plots 
#If dimension or no of dimension is n then there will be nC2 combination of pairs of plots which are difficult to 
#manage and read

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data,hue="species",size=5).map(sns.distplot,"petal_length").add_legend();
plt.show();
#1D PLOT i.e only one feature

# %%
sns.FacetGrid(data,hue="species",size=5).map(sns.distplot,"petal_width").add_legend()
plt.show();

# %%
#TO plot only single feature we use histograms. Histograms plot single feature along x-axis and frequency along y-axis
#The smooth curve along the histogram represents PDF i.r probability distribution function
#we can write the algorithm to predict using single feature by using the graph

# %%
sns.FacetGrid(data,hue="species",size=4).map(sns.distplot,"sepal_width").add_legend()
plt.show();

# %%
sns.FacetGrid(data,hue="species",size=4).map(sns.distplot,"sepal_length").add_legend()
plt.show();

# %%
#By examining the previous 4 graphs i.e histograms based on 4 features we can decide that 
#petal_length is best for univariate analysis of histograms then followed by petal_width feature

# %%
setosa=data.loc[data["species"]=="setosa"]
versicolor=data.loc[data["species"]=="versicolor"]
virginica=data.loc[data["species"]=="virginica"]
#i.e dividing data into three classes

# %%
print("Means:");
print(np.mean(setosa["petal_length"]))
print(np.mean(versicolor["petal_length"]))
print(np.mean(virginica["petal_length"]))
#The mean measures the central tendency of the feature
#By the following results we get to know that petal size of setosa is smaller and petal size of other two are comparable
print("Standard Deviation:")
print(np.std(setosa["petal_length"]))
print(np.std(versicolor["petal_length"]))
print(np.std(virginica["petal_length"]))
# Out:
# Means:
# 1.464
# 4.26
# 5.552
# Standard Deviation:
# 0.17176728442867115
# 0.4651881339845204
# 0.5463478745268441

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data,hue="species",size=4).map(sns.distplot,"petal_length").add_legend()
plt.show()

# %%
#The standard deviation gives the amount of variation of values along the mean value
#But mean and standard deviation can vary in large amount if there is some error in data

# %%
#Therefore we use median of the data sequence for finding the central tendency and does'nt get corrupted by other external 
#wrong values
print("Median:");
print(np.median(setosa["petal_length"]))
print(np.median(versicolor["petal_length"]))
print(np.median(virginica["petal_length"]))
# Out:
# Median:
# 1.5
# 4.35
# 5.55

# %%
counts,bin_edges = np.histogram(setosa['petal_length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
sns.boxplot(x="species",y="petal_length",data=data)
plt.show()
